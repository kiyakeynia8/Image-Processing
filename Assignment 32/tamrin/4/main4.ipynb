# %%
import cv2
import matplotlib.pyplot as plt

# %%
image_low_contrast = cv2.imread("input/4.png",0)

# %%
hist = cv2.calcHist([image_low_contrast], [0], None, [256], [0, 256])

# %%
plt.plot(hist)
plt.show()

# %%
image_high_contrast = cv2.equalizeHist(image_low_contrast)

cv2.imwrite("output assignment_32/f1_result_4.png", image_high_contrast)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6604\1694625315.py in <module>
#       1 image_high_contrast = cv2.equalizeHist(image_low_contrast)
#       2
# ----> 3 cv2.imwrite("output assignment_32/f1_result_4.png", image_high_contrast)
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:783: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
hist = cv2.calcHist([image_high_contrast], [0], None, [256], [0, 256])
plt.plot(hist)
plt.show()
